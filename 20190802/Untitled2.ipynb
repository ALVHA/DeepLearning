# %%
# 필요한 패키지 import
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')    

plt.rcParams['axes.unicode_minus'] = False

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %%
tmp0 = 'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=001&aid=0010998761&isYeonhapFlash=Y&rc=N

response = urlopen(tmp0)

soup = BeautifulSoup(response, 'html.parser')

tmp = soup.find()
# Out:
#   File "<ipython-input-37-79fd63ce2d61>", line 1
#     tmp0 = 'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=001&aid=0010998761&isYeonhapFlash=Y&rc=N
#                                                                                                                ^
# SyntaxError: EOL while scanning string literal

# %%
listo = []
listo.append(tmp.text)

listo
# Out:
# ['\n\n\n\n\n\nARF 개최 방콕서 소형 \'탁구공 폭탄\' 연쇄폭발…최소 3명 부상(종합) : 네이버 뉴스\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\ndocument.domain=\'naver.com\';\nvar _MAIN_NEWS_MENU_ID=\'shm\';\nvar _MAIN_NEWS_SECTION_ID=\'\';\nvar ccsrv=\'cc.naver.com\';\nvar g_ssc=\'news.art\';\nwindow.nsc = g_ssc; \nvar gnb_service=\'news\';\nvar gnb_logout=encodeURIComponent(location.href);\nvar gnb_template=\'gnb_utf8\';\nvar gnb_brightness = 1;\nvar gnb_one_naver = 1;\nvar gnb_searchbox=\'on\';\nvar gnb_shortnick=\'on\';\n\nvar gnb_timestamp = "Fri Aug 02 15:47:31 KST 2019";\n\n\n\n\n\n\n\n\n\n\n\n메인 메뉴로 바로가기\n본문으로 바로가기\n\n\n\n\n\n\n\n\n\n\nNAVER\n뉴스\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n뉴스홈 \n속보\n정치 \n경제 \n사회 \n생활/문화 \n세계 \nIT/과학 \n오피니언 \n포토 \nTV \n랭킹뉴스 \n\n\n\n뉴스 검색\n\n\n\n\n검색\n\n\n\n\n\n\n08.02(금)\n\n헤드라인 뉴스\n\n\n\n\'무모·민폐·적반하장\'…文대통령, 강경용어 총동원해 日규…\n\n\n상산고 때와 달랐다…서울·부산 자사고 10곳 지정취소(종…\n\n\n미·러 중거리핵전력 조약 사실상 폐기…\'新냉전\' 우려\n\n\n北, 이틀 만에 또다시 발사체 시험…靑 “단거리탄도미사일…\n\n\n"살아줘서 고마워요" 실종에서 발견까지…조은누리 양 발…\n\n\n한일, 日경제보복 놓고 공
# ...

# %%
from tqdm import tqdm_notebook

present_candi_text = []

# 검색된 문장을 저장
for n in tqdm_notebook(range(1, 1000, 10)):
    response = urlopen(html.format())

    soup = BeautifulSoup(response, "html.parser")

    tmp = soup.find_all('dl')

    for line in tmp:
        present_candi_text.append(line.text)
        
    time.sleep(0.5)
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-f31edf671c03> in <module>
#       5 # 검색된 문장을 저장
#       6 for n in tqdm_notebook(range(1, 1000, 10)):
# ----> 7     response = urlopen(html.format())
#       8
#       9     soup = BeautifulSoup(response, "html.parser")
#
# NameError: name 'html' is not defined

# %%
present_candi_text
# Out:
# []
